# %% [markdown]
# <a href="https://colab.research.google.com/github/LabCInf/Data-Analysis-Basic/blob/main/Capture_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="250px" src="https://upload.wikimedia.org/wikipedia/commons/archive/f/fb/20161010213812%21Escudo-UdeA.svg" align="left" hspace="10px" vspace="0px"></p>
#
# <h1><b>Introducción al web scraping</b></h1>
#
# <h2>Material preparado por: Jaider Ochoa Gutiérrez y Juan Fernando Pérez Pérez</h2>
#
# Este será un panorama general del uso de herramientas computacionales para hacer scraping de páginas web.
#
# **¡Manos a la obra!**

# %% [markdown]
# # Paso 1: preparar el entorno de trabajo y las librerías

# %%
# !pip install BeautifulSoup4
# !pip install requests
# Out:
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Paso 2: Selección e inspección del sitio web

# %% [markdown]
# **Estructura de la página HTML**
#
# El lenguaje de marcado de hipertexto (HTML) es el lenguaje de marcado estándar para documentos diseñados para mostrarse en un navegador web. HTML describe la estructura de una página web y se puede utilizar con hojas de estilo en cascada (CSS) y un lenguaje de secuencias de comandos como JavaScript para crear sitios web interactivos. HTML consta de una serie de elementos que "le dicen" al navegador cómo mostrar el contenido. Por último, los elementos están representados por etiquetas .
#
# A continuación se muestran algunas etiquetas:
#
#
#
# * La declaración `<!DOCTYPE html>` define este documento como HTML5.
# * El elmento`<html>` es el elemento raíz de una página HTML.
# * La etiqueta `<div>` define una división o una sección en un documento HTML. Suele ser un contenedor para otros elementos.
# * El elemento `<head>` contiene metainformación sobre el documento.
# * El elemento `<title>` especifica un título para el documento.
# * El elemento `<body>` contiene el contenido de la página visible.
# * El elemento `<h1>` define un encabezado grande.
# * El elemento `<p>` define un párrafo.
# * El elemento `<a>` define un hipervínculo.
#
# Las etiquetas HTML normalmente vienen en pares como `<p>` y `</p>`. La primera etiqueta de un par es la etiqueta de apertura, la segunda etiqueta es la etiqueta de cierre. La etiqueta final se escribe como la etiqueta de inicio, pero con una barra inclinada insertada antes del nombre de la etiqueta.

# %%
url = 'https://techcrunch.com/' #Página web de la cual quiero extraer información

# %%
url1 =
# Out:
# 'https://techcrunch.com/'

# %% [markdown]
# # Paso 3: Enviar una solicitud HTML

# %%
url = 'https://techcrunch.com/'
page = requests.get(url) #Hacer la solicitud al sitio web
soup = BeautifulSoup(page.content, 'html.parser')
page #La respuesta que debemos obtener es 200, lo que indica que SÍ podemos "escrapear" el contenido del sitio web
# Out:
# <Response [200]>

# %%
a = soup.find_all('a')
a

# %% [markdown]
# # Paso 4: Extracción de secciones específicas

# %%
titulo = soup.find_all('a', {'class': 'post-block__title__link'})
titulo
# Out:
# [<a class="post-block__title__link" href="https://techcrunch.com/2022/03/12/electric-mini-cooper-se-ev-review/">
#  				The Mini Cooper SE is a fun EV with some catching up to do			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/12/angellist-tiger-global-money/">
#  				AngelList Venture has a new look			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/12/the-startup-growth-paradox/">
#  				The startup growth paradox			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/bored-apes-maker-yuga-labs-acquires-cryptopunks-nft-collection/">
#  				Bored Apes maker Yuga Labs acquires CryptoPunks NFT collection			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/daily-crunch-byjus-founder-chips-in-toward-800m-funding-round-to-reach-22b-valuation/">
#  				Daily Crunch: Byju’s founder chips in toward $800M funding round to reach $22B valuation			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/diamond-age-series-a/">
#  				Diamond Age picks up $50M to lay the foundation for the future of houses built by robots			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/vc-and-native-ukrainian-alex-iskold-is-funneling-money-to-ukranian-refugees-1k-at-a-time/">
#  				VC and native Ukrainian Alex Iskold is funneling money to Ukranian refugees, $1K at a time			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/techcrunch-roundup-tested-tam-tips-no-code-tech-survey-writing-crypto-white-papers/">
#  				TechCrunch+ roundup: Tested TAM tips, no-code tech survey, writing crypto white papers			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/for-founders-who-want-to-launch-apps-being-non-technical-is-not-a-limitation/">
#  				For founders who want to launch apps, ‘being non-technical is not a limitation’			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/hulu-live-tv-to-now-throw-in-an-unlimited-dvr-a-part-of-its-base-plan/">
#  				Hulu + Live TV to now throw in Unlimited DVR as part of its base plan			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/ubisoft-reset-passwords-cyber-incident/">
#  				Ubisoft won’t say why it reset employee passwords after ‘cyber incident’			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/youtube-is-now-blocking-russia-state-affiliated-media-globally/">
#  				YouTube is now blocking Russia state-affiliated media globally			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/were-looking-for-a-few-good-volunteers-for-tc-early-stage/">
#  				We’re looking for a few good volunteers for TC Early Stage			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/russia-instagram-block/">
#  				Russia says it will block Instagram			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/as-tech-companies-suspend-sales-in-russia-what-is-the-actual-business-impact/">
#  				As tech companies suspend sales in Russia, what is the actual business impact?			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/aifi-autonomous-retail-series-b/">
#  				AiFi adds new funding into its cart to expand autonomous retail footprint			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/sorenson-ventures-keeps-focus-on-enterprise-with-new-150m-fund/">
#  				Sorenson Ventures keeps focus on enterprise with new $150M fund			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/netwalker-extradited-bitcoin-seized/">
#  				NetWalker ransomware operator extradited to the US, over $28M in bitcoin seized			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/a-rough-draft-of-the-teetering-startup-landscape-heading-into-q2/">
#  				A rough draft of the teetering startup landscape heading into Q2			</a>,
#  <a class="post-block__title__link" href="https://techcrunch.com/2022/03/11/spacs-are-a-four-letter-word-again/">
#  				SPAC is a four-letter word again			</a>]

# %%
daata=pd.DataFrame()

# %%
#Extraer los títulos de las noticias
titulo = soup.find_all('a', {'class': 'post-block__title__link'}) #En la inspección se debe identificar el atributo o elemento que deseamos extraer
titulo_list = [] #Lista vacía donde vamos a almacer los datos
for x in titulo[1:] : #hacemos un ciclo for para extraer cada unos de los títulos de las noticias
   titulo_list.append((x.get_text())) #Append es un método de pandas que se emplea para almacenar los datos en la lista vacía que hemos creado anteriormente
                                      # .get_text método de beautifulsoup
titulos=pd.DataFrame(titulo_list, columns=['Títulos']) #Guardamos el resultado en un dataframe
titulos #visualimos los datos almacenados en el dataframe
# Out:
#                                               Títulos
# 0    \n\t\t\t\tAngelList Venture has a new look\t\t\t
# 1          \n\t\t\t\tThe startup growth paradox\t\t\t
# 2   \n\t\t\t\tBored Apes maker Yuga Labs acquires ...
# 3   \n\t\t\t\tDaily Crunch: Byju’s founder chips i...
# 4   \n\t\t\t\tDiamond Age picks up $50M to lay the...
# 5   \n\t\t\t\tVC and native Ukrainian Alex Iskold ...
# 6   \n\t\t\t\tTechCrunch+ roundup: Tested TAM tips...
# 7   \n\t\t\t\tFor founders who want to launch apps...
# 8   \n\t\t\t\tHulu + Live TV to now throw in Unlim...
# 9   \n\t\t\t\tUbisoft won’t say why it reset emplo...
# 10  \n\t\t\t\tYouTube is now blocking Russia state...
# 11  \n\t\t\t\tWe’re looking for a few good volunte...
# 12  \n\t\t\t\tRussia says it will block Instagram\...
# 13  \n\t\t\t\tAs tech companies suspend sales in R...
# 14  \n\t\t\t\tAiFi adds new funding into its cart ...
# 15  \n\t\t\t\tSorenson Ventures keeps focus on ent...
# 16  \n\t\t\t\tNetWalker ransomware operator extrad...
# 17  \n\t\t\t\tA rough draft of the teetering start...
# 18   \n\t\t\t\tSPAC is a four-letter word again\t\t\t

# %%
content = soup.find_all('div', {'class': 'post-block__content'})
content
# Out:
# [<div class="post-block__content">
#  		Electrifying a car like the two-door Mini Cooper seems like a brilliant, forehead-slapping “why didn’t we think of this before” kind of concept and Mini certainly agrees. The brand h	</div>,
#  <div class="post-block__content">
#  		AngelList Venture closed its first tranche of institutional funding since spinning out on its own in 2020. The $100 million round valued the business at $4.1 billion. It wasn’t necessarily expected.	</div>,
#  <div class="post-block__content">
#  		Welcome to The TechCrunch Exchange, a weekly startups-and-markets newsletter. It’s inspired by the daily TechCrunch+ column where it gets its name. Want it in your inbox every Saturday? Sign up here	</div>,
#  <div class="post-block__content">
#  		Bored Apes Yacht Club maker Yuga Labs announced Friday that they have acquired the rights to the CryptoPunks and Meebits NFT collections from creator Larva Labs. Bored Apes and CryptoPunks are the two	</div>,
#  <div class="post-block__content">
#  		Hello friends and welcome to Daily Crunch, bringing you the most important startup, tech and venture capital news in a single package.
#  	</div>,
#  <div class="post-block__content">
#  		Hot on the heels from its $8 million fundraise just a few months ago, Diamond Age is back for a top-up, with a $50 million Series A financing to continue its mission to make homeownership more afforda	</div>,
#  <div class="post-block__content">
#  		Alex Iskold is “one of the luckiest people you’ve ever met,” he says from his office in New York. He’s the co-founder and managing partner of a venture firm, 2048 Ventures. He 	</div>,
#  <div class="post-block__content">
#  		For most products, TAM is presented in nine figures or more, but when you're planning to disrupt a billion-dollar market, these numbers can create a lot of cognitive dissonance.	</div>,
#  <div class="post-block__content">
#  		To get a look at how development agency Intent tailors its approach to client needs, we spoke with Wojciech Borkowski, head of business development, and CTO Peter Tuszynski.	</div>,
#  <div class="post-block__content">
#  		In an effort to attract more subscribers to its service, Hulu announced today that it will offer an Unlimited DVR feature as part of its Hulu + Live TV service’s base plan at no additional cost.	</div>,
#  <div class="post-block__content">
#  		Gaming giant Ubisoft has confirmed a cybersecurity incident that led to the mass-reset of company passwords, but has declined to say what the incident actually was. In a brief statement, Ubisoft said:	</div>,
#  <div class="post-block__content">
#  		In a further expansion of its policy responses to Russia’s war in Ukraine, YouTube has said it’s now blocking Kremlin-backed media outlets globally — not just in Europe where two Rus	</div>,
#  <div class="post-block__content">
#  		Our founder-focused summit, TechCrunch Early Stage, is back in-person this April in San Francisco! And we are looking for some incredible volunteers to help us make this event happen. If you are inter	</div>,
#  <div class="post-block__content">
#  		The Russian government has now said it will limit access to Instagram. It’s the latest state restriction targeting mainstream foreign tech platforms since the country’s invasion of Ukraine	</div>,
#  <div class="post-block__content">
#  		Over the last couple of weeks, since Russia first attacked Ukraine, we’ve been hearing about loads of tech companies joining businesses from a variety of industries in suspending sales in Russia	</div>,
#  <div class="post-block__content">
#  		Contactless stores are gaining traction, more so in Europe, but there are some trickling into the U.S., including Atlanta’s Nourish + Bloom Market that opened in January. In that article, we pointed	</div>,
#  <div class="post-block__content">
#  		Sorenson Ventures may not be a household name, but the Lehi, Utah-based firm has quietly backed 30 enterprise startups since 2017 when it launched its initial $100 million fund, some exiting via acqui	</div>,
#  <div class="post-block__content">
#  		A former Canadian government employee accused of carrying out dozens of ransomware attacks has been extradited to the United States, with more than $28 million in bitcoin seized in connection with the	</div>,
#  <div class="post-block__content">
#  		We're no longer in startup Kansas, y'all. If current conditions hold, we're going to see some startups struggle this year. Maybe even a lot of them.	</div>,
#  <div class="post-block__content">
#  		Hello and welcome back to Equity, a podcast about the business of startups, where we unpack the numbers and nuance behind the headlines. This week saw Equity back on the live-taping game, with Mary A	</div>]

# %%
#Extraer el contenido de las noticias (resumen de la noticia)
content = soup.find_all('div', {'class': 'post-block__content'}) #En la inspección se debe identificar el atributo o elemento que deseamos extraer
content_list = []
for i in content[1:]: #hacemos un ciclo para extraer los resúmenes de las noticias
   content_list.append((i.get_text()))

contenido=pd.DataFrame(content_list, columns=['Contenido']) #Guardamos el resultado en un dataframe
contenido
# Out:
#                                             Contenido
# 0   \n\t\tAngelList Venture closed its first tranc...
# 1   \n\t\tWelcome to The TechCrunch Exchange, a we...
# 2   \n\t\tBored Apes Yacht Club maker Yuga Labs an...
# 3   \n\t\tHello friends and welcome to Daily Crunc...
# 4   \n\t\tHot on the heels from its $8 million fun...
# 5   \n\t\tAlex Iskold is “one of the luckiest peop...
# 6   \n\t\tFor most products, TAM is presented in n...
# 7   \n\t\tTo get a look at how development agency ...
# 8   \n\t\tIn an effort to attract more subscribers...
# 9   \n\t\tGaming giant Ubisoft has confirmed a cyb...
# 10  \n\t\tIn a further expansion of its policy res...
# 11  \n\t\tOur founder-focused summit, TechCrunch E...
# 12  \n\t\tThe Russian government has now said it w...
# 13  \n\t\tOver the last couple of weeks, since Rus...
# 14  \n\t\tContactless stores are gaining traction,...
# 15  \n\t\tSorenson Ventures may not be a household...
# 16  \n\t\tA former Canadian government employee ac...
# 17  \n\t\tWe're no longer in startup Kansas, y'all...
# 18  \n\t\tHello and welcome back to Equity, a podc...

# %%
#Extraer el link de la noticia
link = soup.find_all('a', {'class': 'post-block__title__link'}) #En la inspección se debe identificar el atributo o elemento que deseamos extraer
link_list = []
for i in link[1:]: #hacemos un ciclo para extraer cada unos de los enlaces de las noticias
   link_list.append((i.get('href')))

enlaces=pd.DataFrame(link_list, columns=['Enlaces']) #Guardamos el resultado en un dataframe
enlaces
# Out:
#                                               Enlaces
# 0   https://techcrunch.com/2022/03/12/angellist-ti...
# 1   https://techcrunch.com/2022/03/12/the-startup-...
# 2   https://techcrunch.com/2022/03/11/bored-apes-m...
# 3   https://techcrunch.com/2022/03/11/daily-crunch...
# 4   https://techcrunch.com/2022/03/11/diamond-age-...
# 5   https://techcrunch.com/2022/03/11/vc-and-nativ...
# 6   https://techcrunch.com/2022/03/11/techcrunch-r...
# 7   https://techcrunch.com/2022/03/11/for-founders...
# 8   https://techcrunch.com/2022/03/11/hulu-live-tv...
# 9   https://techcrunch.com/2022/03/11/ubisoft-rese...
# 10  https://techcrunch.com/2022/03/11/youtube-is-n...
# 11  https://techcrunch.com/2022/03/11/were-looking...
# 12  https://techcrunch.com/2022/03/11/russia-insta...
# 13  https://techcrunch.com/2022/03/11/as-tech-comp...
# 14  https://techcrunch.com/2022/03/11/aifi-autonom...
# 15  https://techcrunch.com/2022/03/11/sorenson-ven...
# 16  https://techcrunch.com/2022/03/11/netwalker-ex...
# 17  https://techcrunch.com/2022/03/11/a-rough-draf...
# 18  https://techcrunch.com/2022/03/11/spacs-are-a-...

# %%
#Concatenamos todas los dataframe (tablas creadas)
df=pd.concat([titulos,contenido,enlaces],axis=1)
df
# Out:
#                                               Títulos  \
# 0    \n\t\t\t\tAngelList Venture has a new look\t\t\t
# 1          \n\t\t\t\tThe startup growth paradox\t\t\t
# 2   \n\t\t\t\tBored Apes maker Yuga Labs acquires ...
# 3   \n\t\t\t\tDaily Crunch: Byju’s founder chips i...
# 4   \n\t\t\t\tDiamond Age picks up $50M to lay the...
# 5   \n\t\t\t\tVC and native Ukrainian Alex Iskold ...
# 6   \n\t\t\t\tTechCrunch+ roundup: Tested TAM tips...
# 7   \n\t\t\t\tFor founders who want to launch apps...
# 8   \n\t\t\t\tHulu + Live TV to now throw in Unlim...
# 9   \n\t\t\t\tUbisoft won’t say why it reset emplo...
# 10  \n\t\t\t\tYouTube is now blocking Russia state...
# 11  \n\t\t\t\tWe’re looking for a few good volunte...
# 12  \n\t\t\t\tRussia says it will block Instagram\...
# 13  \n\t\t\t\tAs tech companies suspend sales in R...
# 14  \n\t\t\t\tAiFi adds new funding into its cart ...
# 15  \n\t\t\t\tSorenson Ventures keeps focus on ent...
# 16  \n\t\t\t\tNetWalker ransomware operator extrad...
# 17  \n\t\t\t\tA rough draft of the teetering start...
# 18   \n\t\t\t\tSPAC is a four-letter word again\t\t\t
#
#                                             Contenido  \
# 0   \n\t\tAngelList Venture closed its first tranc...
# 1   \n\t\tWelcome to The TechCrunch Exchange, a we...
# 2   \n\t\tBored Apes Yacht Club maker Yuga Labs an...
# 3   \n\t\tHello friends and welcome to Daily Crunc...
# 4   \n\t\tHot on the heels from its $8 million fun...
# 5   \n\t\tAlex Iskold is “one of the luckiest peop...
# 6   \n\t\tFor most products, TAM is presented in n...
# 7   \n\t\tTo get a look at how development agency ...
# 8   \n\t\tIn an effort to attract more subscribers...
# 9   \n\t\tGaming giant Ubisoft has confirmed a cyb...
# 10  \n\t\tIn a further expansion of its policy res...
# 11  \n\t\tOur founder-focused summit, TechCrunch E...
# 12  \n\t\tThe Russian government has now said it w...
# 13  \n\t\tOver the last couple of weeks, since Rus...
# 14  \n\t\tContactless stores are gaining traction,...
# 15  \n\t\tSorenson Ventures may not be a household...
# 16  \n\t\tA former Canadian government employee ac...
# 17  \n\t\tWe're no longer in startup Kansas, y'all...
# 18  \n\t\tHello and welcome back to Equity, a podc...
#
#                                               Enlaces
# 0   https://techcrunch.com/2022/03/12/angellist-ti...
# 1   https://techcrunch.com/2022/03/12/the-startup-...
# 2   https://techcrunch.com/2022/03/11/bored-apes-m...
# 3   https://techcrunch.com/2022/03/11/daily-crunch...
# 4   https://techcrunch.com/2022/03/11/diamond-age-...
# 5   https://techcrunch.com/2022/03/11/vc-and-nativ...
# 6   https://techcrunch.com/2022/03/11/techcrunch-r...
# 7   https://techcrunch.com/2022/03/11/for-founders...
# 8   https://techcrunch.com/2022/03/11/hulu-live-tv...
# 9   https://techcrunch.com/2022/03/11/ubisoft-rese...
# 10  https://techcrunch.com/2022/03/11/youtube-is-n...
# 11  https://techcrunch.com/2022/03/11/were-looking...
# 12  https://techcrunch.com/2022/03/11/russia-insta...
# 13  https://techcrunch.com/2022/03/11/as-tech-comp...
# 14  https://techcrunch.com/2022/03/11/aifi-autonom...
# 15  https://techcrunch.com/2022/03/11/sorenson-ven...
# 16  https://techcrunch.com/2022/03/11/netwalker-ex...
# 17  https://techcrunch.com/2022/03/11/a-rough-draf...
# 18  https://techcrunch.com/2022/03/11/spacs-are-a-...

# %%
#Es importante que de manera constante guardemos nuestros datos en formato JSON o CSV para evitar perderlos y tener que correr el código una y otra vez
df.to_csv("/content/drive/MyDrive/Classroom/Gestión y análisis de datos/ejemplo_1.csv", sep=";",encoding="utf-8-sig")

# %%
#Limpieza del texto
import re #librería de expresiones regulares

def  clean_text(df, text_field):
  patternURLEMAIL=r'(\w+[.]?\w+@(\w+\.)+\w+)|((http:\/\/www\.|https:\/\/www\.|http:\/\/|https:\/\/)?\w+([\-\.]{1}\w+)*\.[a-z]{2,5}(\/)?(([^\s@])*(\/)?)*)'
  patternHashtagMention=r'(@\w+)|(#\w+)'
  # Utilizamos las expresiones regulares anteriores sobre URL, email, hashtag y menciones para quitarlos
  df[text_field] = df[text_field].apply(lambda elem: re.sub(patternURLEMAIL,'', elem))  
  ## Sustituir espacios de más
  df[text_field] = df[text_field].apply(lambda elem: re.sub(r'\s+',' ', elem))

  return df

# %%
dfclean=clean_text(df,"Contenido")
dfclean=clean_text(df,"Títulos")

# %%
dfclean
# Out:
#                                               Títulos  \
# 0                   AngelList Venture has a new look
# 1                         The startup growth paradox
# 2    Bored Apes maker Yuga Labs acquires CryptoPun...
# 3    Daily Crunch: Byju’s founder chips in toward ...
# 4    Diamond Age picks up $50M to lay the foundati...
# 5    VC and native Ukrainian Alex Iskold is funnel...
# 6    TechCrunch+ roundup: Tested TAM tips, no-code...
# 7    For founders who want to launch apps, ‘being ...
# 8    Hulu + Live TV to now throw in Unlimited DVR ...
# 9    Ubisoft won’t say why it reset employee passw...
# 10   YouTube is now blocking Russia state-affiliat...
# 11   We’re looking for a few good volunteers for T...
# 12               Russia says it will block Instagram
# 13   As tech companies suspend sales in Russia, wh...
# 14   AiFi adds new funding into its cart to expand...
# 15   Sorenson Ventures keeps focus on enterprise w...
# 16   NetWalker ransomware operator extradited to t...
# 17   A rough draft of the teetering startup landsc...
# 18                  SPAC is a four-letter word again
#
#                                             Contenido  \
# 0    AngelList Venture closed its first tranche of...
# 1    Welcome to The TechCrunch Exchange, a weekly ...
# 2    Bored Apes Yacht Club maker Yuga Labs announc...
# 3    Hello friends and welcome to Daily Crunch, br...
# 4    Hot on the heels from its $8 million fundrais...
# 5    Alex Iskold is “one of the luckiest people yo...
# 6    For most products, TAM is presented in nine f...
# 7    To get a look at how development agency Inten...
# 8    In an effort to attract more subscribers to i...
# 9    Gaming giant Ubisoft has confirmed a cybersec...
# 10   In a further expansion of its policy response...
# 11   Our founder-focused summit, TechCrunch Early ...
# 12   The Russian government has now said it will l...
# 13   Over the last couple of weeks, since Russia f...
# 14   Contactless stores are gaining traction, more...
# 15   Sorenson Ventures may not be a household name...
# 16   A former Canadian government employee accused...
# 17   We're no longer in startup Kansas, y'all. If ...
# 18   Hello and welcome back to Equity, a podcast a...
#
#                                               Enlaces
# 0   https://techcrunch.com/2022/03/12/angellist-ti...
# 1   https://techcrunch.com/2022/03/12/the-startup-...
# 2   https://techcrunch.com/2022/03/11/bored-apes-m...
# 3   https://techcrunch.com/2022/03/11/daily-crunch...
# 4   https://techcrunch.com/2022/03/11/diamond-age-...
# 5   https://techcrunch.com/2022/03/11/vc-and-nativ...
# 6   https://techcrunch.com/2022/03/11/techcrunch-r...
# 7   https://techcrunch.com/2022/03/11/for-founders...
# 8   https://techcrunch.com/2022/03/11/hulu-live-tv...
# 9   https://techcrunch.com/2022/03/11/ubisoft-rese...
# 10  https://techcrunch.com/2022/03/11/youtube-is-n...
# 11  https://techcrunch.com/2022/03/11/were-looking...
# 12  https://techcrunch.com/2022/03/11/russia-insta...
# 13  https://techcrunch.com/2022/03/11/as-tech-comp...
# 14  https://techcrunch.com/2022/03/11/aifi-autonom...
# 15  https://techcrunch.com/2022/03/11/sorenson-ven...
# 16  https://techcrunch.com/2022/03/11/netwalker-ex...
# 17  https://techcrunch.com/2022/03/11/a-rough-draf...
# 18  https://techcrunch.com/2022/03/11/spacs-are-a-...

# %%
dfclean.Contenido[4]
# Out:
# ' Hot on the heels from its $8 million fundraise just a few months ago, Diamond Age is back for a top-up, with a $50 million Series A financing to continue its mission to make homeownership more afforda '

# %% [markdown]
# # Paso 5: almacenar datos

# %%
#Guardar en formato CSV
dfclean.to_csv("/content/drive/MyDrive/Classroom/Gestión y análisis de datos/ejemplo_2.csv", sep=";",encoding="utf-8-sig")

# %%
dfclean=pd.read_csv("/content/drive/MyDrive/Classroom/Gestión y análisis de datos/ejemplo_2.csv", sep=";",encoding="utf-8-sig")
dfclean

# %%
#Guardar en formato JSON
dfclean.to_json("/content/drive/MyDrive/Classroom/Gestión y análisis de datos//ejemplo_2_clean.json") # exportar a json

# %%
dfclean=pd.read_json("/content/drive/MyDrive/Classroom/Gestión y análisis de datos//ejemplo_2_clean.json")
dfclean
# Out:
#     Unnamed: 0                                            Títulos  \
# 0            0                  AngelList Venture has a new look
# 1            1                        The startup growth paradox
# 2            2   Bored Apes maker Yuga Labs acquires CryptoPun...
# 3            3   Daily Crunch: Byju’s founder chips in toward ...
# 4            4   Diamond Age picks up $50M to lay the foundati...
# 5            5   VC and native Ukrainian Alex Iskold is funnel...
# 6            6   TechCrunch+ roundup: Tested TAM tips, no-code...
# 7            7   For founders who want to launch apps, ‘being ...
# 8            8   Hulu + Live TV to now throw in Unlimited DVR ...
# 9            9   Ubisoft won’t say why it reset employee passw...
# 10          10   YouTube is now blocking Russia state-affiliat...
# 11          11   We’re looking for a few good volunteers for T...
# 12          12               Russia says it will block Instagram
# 13          13   As tech companies suspend sales in Russia, wh...
# 14          14   AiFi adds new funding into its cart to expand...
# 15          15   Sorenson Ventures keeps focus on enterprise w...
# 16          16   NetWalker ransomware operator extradited to t...
# 17          17   A rough draft of the teetering startup landsc...
# 18          18                  SPAC is a four-letter word again
#
#                                             Contenido  \
# 0    AngelList Venture closed its first tranche of...
# 1    Welcome to The TechCrunch Exchange, a weekly ...
# 2    Bored Apes Yacht Club maker Yuga Labs announc...
# 3    Hello friends and welcome to Daily Crunch, br...
# 4    Hot on the heels from its $8 million fundrais...
# 5    Alex Iskold is “one of the luckiest people yo...
# 6    For most products, TAM is presented in nine f...
# 7    To get a look at how development agency Inten...
# 8    In an effort to attract more subscribers to i...
# 9    Gaming giant Ubisoft has confirmed a cybersec...
# 10   In a further expansion of its policy response...
# 11   Our founder-focused summit, TechCrunch Early ...
# 12   The Russian government has now said it will l...
# 13   Over the last couple of weeks, since Russia f...
# 14   Contactless stores are gaining traction, more...
# 15   Sorenson Ventures may not be a household name...
# 16   A former Canadian government employee accused...
# 17   We're no longer in startup Kansas, y'all. If ...
# 18   Hello and welcome back to Equity, a podcast a...
#
#                                               Enlaces
# 0   https://techcrunch.com/2022/03/12/angellist-ti...
# 1   https://techcrunch.com/2022/03/12/the-startup-...
# 2   https://techcrunch.com/2022/03/11/bored-apes-m...
# 3   https://techcrunch.com/2022/03/11/daily-crunch...
# 4   https://techcrunch.com/2022/03/11/diamond-age-...
# 5   https://techcrunch.com/2022/03/11/vc-and-nativ...
# 6   https://techcrunch.com/2022/03/11/techcrunch-r...
# 7   https://techcrunch.com/2022/03/11/for-founders...
# 8   https://techcrunch.com/2022/03/11/hulu-live-tv...
# 9   https://techcrunch.com/2022/03/11/ubisoft-rese...
# 10  https://techcrunch.com/2022/03/11/youtube-is-n...
# 11  https://techcrunch.com/2022/03/11/were-looking...
# 12  https://techcrunch.com/2022/03/11/russia-insta...
# 13  https://techcrunch.com/2022/03/11/as-tech-comp...
# 14  https://techcrunch.com/2022/03/11/aifi-autonom...
# 15  https://techcrunch.com/2022/03/11/sorenson-ven...
# 16  https://techcrunch.com/2022/03/11/netwalker-ex...
# 17  https://techcrunch.com/2022/03/11/a-rough-draf...
# 18  https://techcrunch.com/2022/03/11/spacs-are-a-...

# %% [markdown]
# # Referencias
#
#
# [Documentación de BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# [Documentación de re](https://docs.python.org/3/library/re.html)
#
# [Documentación de request](https://docs.python-requests.org/en/latest/)
#
# [Documentación de Pandas](https://pandas.pydata.org/)
#
# [Documentación de HTML](https://html.spec.whatwg.org/multipage/)
#
# [Documentación JSON](https://www.json.org/json-en.html)
